# %% [markdown]
# # Weather Analysis
#
# ## Analyze [temp, wind-speed, humidity, cloudiness] vs. Latitude
#
# ### Import Dependencies & Setup
# ### Generate list of 500+ cities from random lat/long coordinates
# ### API call with Openweathermap
# ### Visualize Data with matplotlib

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

#Importing this to automate the visualizations time created
from datetime import datetime

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# # Output File (CSV)
# output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
citylats = []
citylngs = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        citylats.append(lat_lng[0])
        citylngs.append(lat_lng[1])

        # Print the city count to confirm sufficient count
print(f"There are {len(cities)} cities saved")
print(f"There are {len(citylats)} lats saved")
# Out:
# There are 647 cities saved
# There are 647 lats saved

# %%
#################### Creating DataFrame #####################
# Creating empty colummns that will be populated when requesting data via API

temp_dict ={
    "City" : cities,
    "Lat" : citylats,
    "Lng" : citylngs,
    "Temp":"",
    "Humidity":"",
    "Cloudiness":"",
    "Wind Speed":"",
    "City ID":""}

tempDict = pd.DataFrame(temp_dict)
tempDict.head()
# Out:
#         City        Lat         Lng Temp Humidity Cloudiness Wind Speed  \
# 0   katsuura  25.597566  147.718438
# 1   saleaula   1.033213 -166.030762
# 2  ketchikan  57.157112 -130.721199
# 3    lubango -16.127035   14.275125
# 4     shaowu  27.471167  117.356119
#
#   City ID
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Perform API Calls

# %%
#################### OpenWeatherMap API Key #####################
# 
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key + "&q="

### Creating a timestamp so we know exactly when the request was made to gather the weather data
### The timestamp is in this cell specifically to capture the request time, that way visualizations can be made 'whenver'
### and it will still refer to the correct time for when the data was captured.
ts = pd.to_datetime(datetime.now())

#Creating Counters to keep track of cities with temp info and cities without temp info
city_number = 0
noinfo = 0

for index, row in tempDict.iterrows():
    city = row['City']
    
    #API Call
    response = requests.get(url + city).json()
    
    try:
       
        
        tempDict.loc[index, 'Temp'] = response['main']['temp']
        tempDict.loc[index, 'Humidity'] = response['main']['humidity']
        tempDict.loc[index, 'Cloudiness'] = response['clouds']['all']
        tempDict.loc[index, 'Wind Speed'] = response['wind']['speed']
        tempDict.loc[index, 'City ID'] = response['id']
        city_number +=1
        print(f"City Number: {city_number} - City Name: {city}")
    except KeyError:
        
#         print(f"{city} did not have a temp")
        noinfo +=1
        continue

print("---------------------------------")
print(f"There are {city_number} cities that DO have info")
print(f"there are {noinfo} cities that DO NOT have any info")
print("----------------------------------")
# Out:
# City Number: 1 - City Name: katsuura
# City Number: 2 - City Name: ketchikan
# City Number: 3 - City Name: lubango
# City Number: 4 - City Name: shaowu
# City Number: 5 - City Name: vaini
# City Number: 6 - City Name: balikpapan
# City Number: 7 - City Name: saldanha
# City Number: 8 - City Name: victoria
# City Number: 9 - City Name: bethanien
# City Number: 10 - City Name: bereda
# City Number: 11 - City Name: norman wells
# City Number: 12 - City Name: kapaa
# City Number: 13 - City Name: port blair
# City Number: 14 - City Name: saskylakh
# City Number: 15 - City Name: qaanaaq
# City Number: 16 - City Name: jamestown
# City Number: 17 - City Name: kenitra
# City Number: 18 - City Name: yellowknife
# City Number: 19 - City Name: atuona
# City Number: 20 - City Name: ugoofaaru
# City Number: 21 - City Name: hermanus
# City Number: 22 - City Name: port elizabeth
# City Number: 23 - City Name: geraldton
# City Number: 24 - City Name: sabang
# City Number: 25 - City Name: thompson
# City Number: 26 - City Name: bethel
# City Number: 27 - City Name: nova olinda do norte
# City Number: 28 - City Name: vardo
# City Number: 29 - City Name: hithadhoo
# City Number: 30 - City Name: lingao
# City Number: 31 - City Name: vanavara
# City Number: 32 - City Name: vanimo
# City Number: 33 - City Name: mount isa
# City Number: 34 - City Name: greenville
# City Number: 35 - City Name: rikitea
# City Number: 36 - City Name: carutapera
# City Number: 37 - City Name: ushuaia
# City Number: 38 - City Name: ahipara
# City Number: 39 - City Name: albany
# City Number: 40 - City Name: puerto ayora
# City Number: 41 - City Name: tura
# City Number: 42 - City Name: barrow
# City Number: 43 - City Name: carnarvon
# City Number: 44 - City Name: guerrero negro
# City Number: 45 - City Name: jiangyou
# City Number: 46 - City Name: lebu
# City Number: 47 - City Name: new norfolk
# City Number: 48 - City Name: nanortalik
# City Number: 49 - City Name: mataura
# City Number: 50 - City Name: pangody
# City Number: 51 - City Name: port hardy
# City Number: 52 - City Name: punta arenas
# City Number: 53 - City Name: tawang
# City Number: 54 - City Name: dingle
# City Number: 55 - City Name: pervomayskoye
# City Number: 56 - City Name: xuddur
# City Number: 57 - City Name: castro
# City Number: 58 - City Name: magistralnyy
# City Number: 59 - City Name: artyom
# City Number: 60 - City Name: nouadhibou
# City Number: 61 - City Name: kilosa
# City Number: 62 - City Name: mount pleasant
# City Number: 63 - City Name: makakilo city
# City Number: 64 - City Name: panama city
# City Number: 65 - City Name: gulkevichi
# City Number: 66 - City Name: pangnirtung
# City Number: 67 - City Name: mahebourg
# City Number: 68 - City Name: tiksi
# City Number: 69 - City Name: naze
# City Number: 70 - City Name: bredasdorp
# City Number: 71 - City Name: codajas
# City Number: 72 - City Name: lokosovo
# City Number: 73 - City Name: san quintin
# City Number: 74 - City Name: busselton
# City Number: 75 - City Name: hilo
# City Number: 76 - City Name: aloleng
# City Number: 77 - City Name: lagoa
# City Number: 78 - City Name: mar del plata
# City Number: 79 - City Name: dagda
# City Number: 80 - City Name: airai
# City Number: 81 - City Name: the valley
# City Number: 82 - City Name: kodiak
# City Number: 83 - City Name: bend
# City Number: 84 - City Name: saint-philippe
# City Number: 85 - City Name: sao joao da barra
# City Number: 86 - City Name: zhigansk
# City Number: 87 - City Name: rantepao
# City Number: 88 - City Name: meadow lake
# City Number: 89 - City Name: kindu
# City Number: 90 - City Name: pangkalanbuun
# City Number: 91 - City Name: atar
# City Number: 92 - City Name: adrar
# City Number: 93 - City Name: valdez
# City Number: 94 - City Name: kodinsk
# City Number: 95 - City Name: christchurch
# City Number: 96 - City Name: kudahuvadhoo
# City Number: 97 - City Name: quthing
# City Number: 98 - City Name: oneonta
# City Number: 99 - City Name: maniitsoq
# City Number: 100 - City Name: jiupu
# City Number: 101 - City Name: high level
# City Number: 102 - City Name: kiama
# City Number: 103 - City Name: khatanga
# City Number: 104 - City Name: cape town
# City Number: 105 - City Name: avarua
# City Number: 106 - City Name: sambava
# City Number: 107 - City Name: deloraine
# City Number: 108 - City Name: hobart
# City Number: 109 - City Name: cayenne
# City Number: 110 - City Name: bitung
# City Number: 111 - City Name: beloha
# City Number: 112 - City Name: genhe
# City Number: 113 - City Name: vila velha
# City Number: 114 - City Name: port alfred
# City Number: 115 - City Name: hualmay
# City Number: 116 - City Name: staffanstorp
# City Number: 117 - City Name: srednekolymsk
# City Number: 118 - City Name: kirkwall
# City Number: 119 - City Name: acapulco
# City Number: 120 - City Name: ossora
# City Number: 121 - City Name: arraial do cabo
# City Number: 122 - City Name: turukhansk
# City Number: 123 - City Name: bagotville
# City Number: 124 - City Name: sao filipe
# City Number: 125 - City Name: ponta do sol
# City Number: 126 - City Name: cherskiy
# City Number: 127 - City Name: kruisfontein
# City Number: 128 - City Name: oromocto
# City Number: 129 - City Name: chokurdakh
# City Number: 130 - City Name: camocim
# City Number: 131 - City Name: lexington
# City Number: 132 - City Name: candolim
# City Number: 133 - City Name: gat
# City Number: 134 - City Name: daru
# City Number: 135 - City Name: faanui
# City Number: 136 - City Name: coquimbo
# City Number: 137 - City Name: octeville
# City Number: 138 - City Name: lillooet
# City Number: 139 - City Name: pemba
# City Number: 140 - City Name: pasinler
# City Number: 141 - City Name: craig
# City Number: 142 - City Name: samarai
# City Number: 143 - City Name: baie-comeau
# City Number: 144 - City Name: haines junction
# City Number: 145 - City Name: cabo san lucas
# City Number: 146 - City Name: butaritari
# City Number: 147 - City Name: maxixe
# City Number: 148 - City Name: iqaluit
# City Number: 149 - City Name: vao
# City Number: 150 - City Name: joao camara
# City Number: 151 - City Name: neryungri
# City Number: 152 - City Name: te anau
# City Number: 153 - City Name: bluff
# City Number: 154 - City Name: petropavlovsk-kamchatskiy
# City Number: 155 - City Name: sidrolandia
# City Number: 156 - City Name: isangel
# City Number: 157 - City Name: isla vista
# City Number: 158 - City Name: alta floresta
# City Number: 159 - City Name: ponnani
# City Number: 160 - City Name: la palma
# City Number: 161 - City Name: noshiro
# City Number: 162 - City Name: emerald
# City Number: 163 - City Name: ribeira grande
# City Number: 164 - City Name: odienne
# City Number: 165 - City Name: birakan
# City Number: 166 - City Name: lompoc
# City Number: 167 - City Name: antofagasta
# City Number: 168 - City Name: torbay
# City Number: 169 - City Name: camden
# City Number: 170 - City Name: bozeman
# City Number: 171 - City Name: port hedland
# City Number: 172 - City Name: necochea
# City Number: 173 - City Name: gelibolu
# City Number: 174 - City Name: oudtshoorn
# City Number: 175 - City Name: jacareacanga
# City Number: 176 - City Name: lata
# City Number: 177 - City Name: tasiilaq
# City Number: 178 - City Name: trelew
# City Number: 179 - City Name: constitucion
# City Number: 180 - City Name: bulgan
# City Number: 181 - City Name: dongsheng
# City Number: 182 - City Name: saint george
# City Number: 183 - City Name: kavieng
# City Number: 184 - City Name: peleduy
# City Number: 185 - City Name: trincomalee
# City Number: 186 - City Name: micheweni
# City Number: 187 - City Name: mogadishu
# City Number: 188 - City Name: aklavik
# City Number: 189 - City Name: requena
# City Number: 190 - City Name: agropoli
# City Number: 191 - City Name: axim
# City Number: 192 - City Name: yulara
# City Number: 193 - City Name: tamiahua
# City Number: 194 - City Name: robertsport
# City Number: 195 - City Name: kawalu
# City Number: 196 - City Name: biak
# City Number: 197 - City Name: liwale
# City Number: 198 - City Name: marsh harbour
# City Number: 199 - City Name: georgetown
# City Number: 200 - City Name: amapa
# City Number: 201 - City Name: omsukchan
# City Number: 202 - City Name: cockburn town
# City Number: 203 - City Name: saint-joseph
# City Number: 204 - City Name: kanye
# City Number: 205 - City Name: imbituba
# City Number: 206 - City Name: nantucket
# City Number: 207 - City Name: arlit
# City Number: 208 - City Name: alexandria
# City Number: 209 - City Name: provideniya
# City Number: 210 - City Name: yueyang
# City Number: 211 - City Name: lewistown
# City Number: 212 - City Name: hovd
# City Number: 213 - City Name: korhogo
# City Number: 214 - City Name: bambous virieux
# City Number: 215 - City Name: trapani
# City Number: 216 - City Name: beliator
# City Number: 217 - City Name: pevek
# City Number: 218 - City Name: komatsu
# City Number: 219 - City Name: scarborough
# City Number: 220 - City Name: chapais
# City Number: 221 - City Name: half moon bay
# City Number: 222 - City Name: souillac
# City Number: 223 - City Name: barranca
# City Number: 224 - City Name: hasaki
# City Number: 225 - City Name: saint anthony
# City Number: 226 - City Name: araouane
# City Number: 227 - City Name: luderitz
# City Number: 228 - City Name: quatre cocos
# City Number: 229 - City Name: yinchuan
# City Number: 230 - City Name: severo-kurilsk
# City Number: 231 - City Name: nikolskoye
# City Number: 232 - City Name: methoni
# City Number: 233 - City Name: east london
# City Number: 234 - City Name: verkhnetulomskiy
# City Number: 235 - City Name: mecca
# City Number: 236 - City Name: tuktoyaktuk
# City Number: 237 - City Name: henties bay
# City Number: 238 - City Name: rafai
# City Number: 239 - City Name: inirida
# City Number: 240 - City Name: fairbanks
# City Number: 241 - City Name: akonolinga
# City Number: 242 - City Name: pitkyaranta
# City Number: 243 - City Name: darhan
# City Number: 244 - City Name: aksarka
# City Number: 245 - City Name: bogorodskoye
# City Number: 246 - City Name: doha
# City Number: 247 - City Name: tabas
# City Number: 248 - City Name: sindor
# City Number: 249 - City Name: timaru
# City Number: 250 - City Name: nome
# City Number: 251 - City Name: upernavik
# City Number: 252 - City Name: paraiso
# City Number: 253 - City Name: cavalcante
# City Number: 254 - City Name: aranos
# City Number: 255 - City Name: chumikan
# City Number: 256 - City Name: dikson
# City Number: 257 - City Name: cootehill
# City Number: 258 - City Name: clyde river
# City Number: 259 - City Name: omboue
# City Number: 260 - City Name: vredendal
# City Number: 261 - City Name: tuatapere
# City Number: 262 - City Name: novobirilyussy
# City Number: 263 - City Name: tilichiki
# City Number: 264 - City Name: camocim de sao felix
# City Number: 265 - City Name: sobolevo
# City Number: 266 - City Name: hushitai
# City Number: 267 - City Name: dayong
# City Number: 268 - City Name: san policarpo
# City Number: 269 - City Name: talnakh
# City Number: 270 - City Name: naryan-mar
# City Number: 271 - City Name: lorengau
# City Number: 272 - City Name: sinnamary
# City Number: 273 - City Name: butte
# City Number: 274 - City Name: ancud
# City Number: 275 - City Name: dong hoi
# City Number: 276 - City Name: praia da vitoria
# City Number: 277 - City Name: murgab
# City Number: 278 - City Name: megion
# City Number: 279 - City Name: karratha
# City Number: 280 - City Name: san cristobal
# City Number: 281 - City Name: ostrovnoy
# City Number: 282 - City Name: nuuk
# City Number: 283 - City Name: nemuro
# City Number: 284 - City Name: mikhaylovka
# City Number: 285 - City Name: magadi
# City Number: 286 - City Name: san patricio
# City Number: 287 - City Name: tabuk
# City Number: 288 - City Name: avera
# City Number: 289 - City Name: san lazaro
# City Number: 290 - City Name: pisco
# City Number: 291 - City Name: shingu
# City Number: 292 - City Name: moerai
# City Number: 293 - City Name: kargasok
# City Number: 294 - City Name: namatanai
# City Number: 295 - City Name: los llanos de aridane
# City Number: 296 - City Name: bunia
# City Number: 297 - City Name: dryden
# City Number: 298 - City Name: beringovskiy
# City Number: 299 - City Name: mocuba
# City Number: 300 - City Name: bubaque
# City Number: 301 - City Name: buala
# City Number: 302 - City Name: boa vista
# City Number: 303 - City Name: guano
# City Number: 304 - City Name: sahbuz
# City Number: 305 - City Name: baykit
# City Number: 306 - City Name: ternate
# City Number: 307 - City Name: gaya
# City Number: 308 - City Name: sturgeon bay
# City Number: 309 - City Name: sur
# City Number: 310 - City Name: san vicente
# City Number: 311 - City Name: qom
# City Number: 312 - City Name: ambilobe
# City Number: 313 - City Name: celestun
# City Number: 314 - City Name: xining
# City Number: 315 - City Name: kirksville
# City Number: 316 - City Name: jumla
# City Number: 317 - City Name: lakeside
# City Number: 318 - City Name: charters towers
# City Number: 319 - City Name: masvingo
# City Number: 320 - City Name: kungurtug
# City Number: 321 - City Name: pacific grove
# City Number: 322 - City Name: sorong
# City Number: 323 - City Name: sibolga
# City Number: 324 - City Name: nurlat
# City Number: 325 - City Name: ughelli
# City Number: 326 - City Name: gamba
# City Number: 327 - City Name: oxbow
# City Number: 328 - City Name: innisfail
# City Number: 329 - City Name: vondrozo
# City Number: 330 - City Name: kitimat
# City Number: 331 - City Name: terrace
# City Number: 332 - City Name: buenos aires
# City Number: 333 - City Name: north bend
# City Number: 334 - City Name: kahului
# City Number: 335 - City Name: muisne
# City Number: 336 - City Name: uspenskaya
# City Number: 337 - City Name: beyneu
# City Number: 338 - City Name: bilibino
# City Number: 339 - City Name: boca do acre
# City Number: 340 - City Name: salalah
# City Number: 341 - City Name: aasiaat
# City Number: 342 - City Name: arvi
# City Number: 343 - City Name: tarakan
# City Number: 344 - City Name: esperance
# City Number: 345 - City Name: chuy
# City Number: 346 - City Name: novyy urgal
# City Number: 347 - City Name: izumo
# City Number: 348 - City Name: takoradi
# City Number: 349 - City Name: padang
# City Number: 350 - City Name: kavaratti
# City Number: 351 - City Name: cidreira
# City Number: 352 - City Name: road town
# City Number: 353 - City Name: oranjestad
# City Number: 354 - City Name: bose
# City Number: 355 - City Name: klaksvik
# City Number: 356 - City Name: comodoro rivadavia
# City Number: 357 - City Name: tazovskiy
# City Number: 358 - City Name: lengshuitan
# City Number: 359 - City Name: saint-pierre
# City Number: 360 - City Name: brae
# City Number: 361 - City Name: uarini
# City Number: 362 - City Name: tuensang
# City Number: 363 - City Name: kuching
# City Number: 364 - City Name: faya
# City Number: 365 - City Name: anloga
# City Number: 366 - City Name: narsaq
# City Number: 367 - City Name: atherton
# City Number: 368 - City Name: huarmey
# City Number: 369 - City Name: atchison
# City Number: 370 - City Name: beian
# City Number: 371 - City Name: hoi an
# City Number: 372 - City Name: sola
# City Number: 373 - City Name: monza
# City Number: 374 - City Name: lasa
# City Number: 375 - City Name: buraydah
# City Number: 376 - City Name: coihaique
# City Number: 377 - City Name: kaitangata
# City Number: 378 - City Name: margate
# City Number: 379 - City Name: romitan
# City Number: 380 - City Name: paamiut
# City Number: 381 - City Name: nieuwpoort
# City Number: 382 - City Name: ratnagiri
# City Number: 383 - City Name: muriti
# City Number: 384 - City Name: banda aceh
# City Number: 385 - City Name: grindavik
# City Number: 386 - City Name: ekibastuz
# City Number: 387 - City Name: fredericton
# City Number: 388 - City Name: abbeyfeale
# City Number: 389 - City Name: campbell river
# City Number: 390 - City Name: poum
# City Number: 391 - City Name: eyl
# City Number: 392 - City Name: oktyabrskoye
# City Number: 393 - City Name: trinidad
# City Number: 394 - City Name: polunochnoye
# City Number: 395 - City Name: bjerringbro
# City Number: 396 - City Name: colares
# City Number: 397 - City Name: ryotsu
# City Number: 398 - City Name: hofn
# City Number: 399 - City Name: sal rei
# City Number: 400 - City Name: alawalpur
# City Number: 401 - City Name: enkoping
# City Number: 402 - City Name: rujewa
# City Number: 403 - City Name: hokitika
# City Number: 404 - City Name: olovyannaya
# City Number: 405 - City Name: kuryk
# City Number: 406 - City Name: morondava
# City Number: 407 - City Name: batamshinskiy
# City Number: 408 - City Name: waingapu
# City Number: 409 - City Name: tomatlan
# City Number: 410 - City Name: yeppoon
# City Number: 411 - City Name: russell
# City Number: 412 - City Name: menongue
# City Number: 413 - City Name: mount gambier
# City Number: 414 - City Name: pringsewu
# City Number: 415 - City Name: bay roberts
# City Number: 416 - City Name: nedryhayliv
# City Number: 417 - City Name: balabac
# City Number: 418 - City Name: marseille
# City Number: 419 - City Name: paita
# City Number: 420 - City Name: balkanabat
# City Number: 421 - City Name: batagay-alyta
# City Number: 422 - City Name: porto novo
# City Number: 423 - City Name: dudinka
# City Number: 424 - City Name: dongying
# City Number: 425 - City Name: lyaskelya
# City Number: 426 - City Name: senno
# City Number: 427 - City Name: maamba
# City Number: 428 - City Name: smolenka
# City Number: 429 - City Name: soubre
# City Number: 430 - City Name: coahuayana
# City Number: 431 - City Name: bathsheba
# City Number: 432 - City Name: sorsk
# City Number: 433 - City Name: hamilton
# City Number: 434 - City Name: mumford
# City Number: 435 - City Name: kovur
# City Number: 436 - City Name: shimoda
# City Number: 437 - City Name: zhangye
# City Number: 438 - City Name: angoche
# City Number: 439 - City Name: kissimmee
# City Number: 440 - City Name: komsomolskiy
# City Number: 441 - City Name: broken hill
# City Number: 442 - City Name: raudeberg
# City Number: 443 - City Name: flin flon
# City Number: 444 - City Name: miri
# City Number: 445 - City Name: zeya
# City Number: 446 - City Name: bahir dar
# City Number: 447 - City Name: denpasar
# City Number: 448 - City Name: kanniyakumari
# City Number: 449 - City Name: cervo
# City Number: 450 - City Name: umm lajj
# City Number: 451 - City Name: punta alta
# City Number: 452 - City Name: port macquarie
# City Number: 453 - City Name: aykhal
# City Number: 454 - City Name: effingham
# City Number: 455 - City Name: kiunga
# City Number: 456 - City Name: la ronge
# City Number: 457 - City Name: peniche
# City Number: 458 - City Name: kaeo
# City Number: 459 - City Name: eirunepe
# City Number: 460 - City Name: rocha
# City Number: 461 - City Name: ende
# City Number: 462 - City Name: antsohihy
# City Number: 463 - City Name: erenhot
# City Number: 464 - City Name: suntar
# City Number: 465 - City Name: itarema
# City Number: 466 - City Name: port lincoln
# City Number: 467 - City Name: olenino
# City Number: 468 - City Name: longyearbyen
# City Number: 469 - City Name: verkhoyansk
# City Number: 470 - City Name: marrakesh
# City Number: 471 - City Name: palora
# City Number: 472 - City Name: cedar city
# City Number: 473 - City Name: sungurlu
# City Number: 474 - City Name: cilegon
# City Number: 475 - City Name: manadhoo
# City Number: 476 - City Name: shahrud
# City Number: 477 - City Name: yining
# City Number: 478 - City Name: tonekabon
# City Number: 479 - City Name: yumen
# City Number: 480 - City Name: san carlos
# City Number: 481 - City Name: port-cartier
# City Number: 482 - City Name: kerema
# City Number: 483 - City Name: spornoye
# City Number: 484 - City Name: derzhavinsk
# City Number: 485 - City Name: moroto
# City Number: 486 - City Name: anchorage
# City Number: 487 - City Name: yashan
# City Number: 488 - City Name: nicoya
# City Number: 489 - City Name: mezen
# City Number: 490 - City Name: kirakira
# City Number: 491 - City Name: baiquan
# City Number: 492 - City Name: przhevalskoye
# City Number: 493 - City Name: santa isabel do rio negro
# City Number: 494 - City Name: lohja
# City Number: 495 - City Name: boyuibe
# City Number: 496 - City Name: alice springs
# City Number: 497 - City Name: broome
# City Number: 498 - City Name: marion
# City Number: 499 - City Name: kalemie
# City Number: 500 - City Name: puerto asis
# City Number: 501 - City Name: leningradskiy
# City Number: 502 - City Name: khovu-aksy
# City Number: 503 - City Name: preobrazheniye
# City Number: 504 - City Name: brigantine
# City Number: 505 - City Name: sitka
# City Number: 506 - City Name: port jervis
# City Number: 507 - City Name: basco
# City Number: 508 - City Name: llangefni
# City Number: 509 - City Name: monrovia
# City Number: 510 - City Name: nagai
# City Number: 511 - City Name: hernani
# City Number: 512 - City Name: richards bay
# City Number: 513 - City Name: wasilla
# City Number: 514 - City Name: gorontalo
# City Number: 515 - City Name: belyy yar
# City Number: 516 - City Name: neuquen
# City Number: 517 - City Name: porto velho
# City Number: 518 - City Name: tomakomai
# City Number: 519 - City Name: ilulissat
# City Number: 520 - City Name: lavrentiya
# City Number: 521 - City Name: tutoia
# City Number: 522 - City Name: kapuskasing
# City Number: 523 - City Name: taoudenni
# City Number: 524 - City Name: kyzyl-suu
# City Number: 525 - City Name: mareeba
# City Number: 526 - City Name: nova soure
# City Number: 527 - City Name: kalianget
# City Number: 528 - City Name: cassilandia
# City Number: 529 - City Name: forrest city
# City Number: 530 - City Name: lalmohan
# City Number: 531 - City Name: okha
# City Number: 532 - City Name: hobyo
# City Number: 533 - City Name: hit
# City Number: 534 - City Name: wabag
# City Number: 535 - City Name: svetlogorsk
# City Number: 536 - City Name: puro
# City Number: 537 - City Name: belgrade
# City Number: 538 - City Name: mopipi
# City Number: 539 - City Name: okhotsk
# City Number: 540 - City Name: puerto carreno
# City Number: 541 - City Name: davila
# City Number: 542 - City Name: jiexiu
# City Number: 543 - City Name: roma
# City Number: 544 - City Name: gbarnga
# City Number: 545 - City Name: yangambi
# City Number: 546 - City Name: dzerzhinsk
# City Number: 547 - City Name: sarangani
# City Number: 548 - City Name: kieta
# City Number: 549 - City Name: kourou
# City Number: 550 - City Name: inhambane
# City Number: 551 - City Name: cairns
# City Number: 552 - City Name: mayo
# City Number: 553 - City Name: bonavista
# City Number: 554 - City Name: kurchum
# City Number: 555 - City Name: shenjiamen
# City Number: 556 - City Name: staryy nadym
# City Number: 557 - City Name: ginir
# City Number: 558 - City Name: arman
# City Number: 559 - City Name: jaisinghnagar
# City Number: 560 - City Name: san luis
# City Number: 561 - City Name: andilamena
# City Number: 562 - City Name: birao
# City Number: 563 - City Name: wellington
# City Number: 564 - City Name: forest grove
# City Number: 565 - City Name: redlands
# City Number: 566 - City Name: visnes
# City Number: 567 - City Name: floro
# City Number: 568 - City Name: san juan
# City Number: 569 - City Name: muchkapskiy
# City Number: 570 - City Name: whitehorse
# City Number: 571 - City Name: tautira
# City Number: 572 - City Name: mahibadhoo
# ---------------------------------
# There are 572 cities that DO have info
# there are 75 cities that DO NOT have any info
# ----------------------------------

# %%
################## Summary of Data and how many cities were removed becuase they didn't have any data #################

# Replace empty strings in the Temp column with NaN
tempDict['Temp'].replace('',np.nan, inplace=True)

# Create new DF with only cities that have temperature data
Complete_WeatherDF = tempDict.dropna(subset=['Temp'])

print(f"The original tempDict Data Frame's shape is: {tempDict.shape}")
print(f"The new DataFrame including only valid cities with temperatures shape is: {Complete_WeatherDF.shape}")
print(f"There were {noinfo} cities in the original tempDict Data Frame that did not have any info.")
Complete_WeatherDF.head()
# Out:
# The original tempDict Data Frame's shape is: (647, 8)
# The new DataFrame including only valid cities with temperatures shape is: (572, 8)
# There were 75 cities in the original tempDict Data Frame that did not have any info.
#         City        Lat         Lng   Temp Humidity Cloudiness Wind Speed  \
# 0   katsuura  25.597566  147.718438  41.92       86         75       6.93
# 2  ketchikan  57.157112 -130.721199  40.17       69         20       8.05
# 3    lubango -16.127035   14.275125  68.89       64          0       1.59
# 4     shaowu  27.471167  117.356119  49.67      100         92       2.37
# 6      vaini -71.220216 -168.771826  64.07       92          0        1.7
#
#    City ID
# 0  1865309
# 2  5554428
# 3  3347762
# 4  1795857
# 6  1273574

# %%
############### Saving Data Frame to CSV File #########################

### This CSF file shows ONLY the cities that returned valid temperatures and were used for the visualizations below
Complete_WeatherDF.to_csv('data/Complete_WeatherDF.csv')

### This CSV file shows all of the cities that were originally generated, including those that did not return a temperature.
tempDict.to_csv('data/tempDict_DF.csv')

# %%
############## Temperature vs Latitude #######################
y = Complete_WeatherDF.Temp
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f"Temperature(F) vs. Latitude\nTime Stamp: {ts}")
plt.xlabel('Latitude')
plt.ylabel('Temperature(F)')
plt.savefig('img/WeatherPy_Temp.vs.Lat.png')
plt.show()

# %%
############## Humidity vs Latitude #######################
y = Complete_WeatherDF.Humidity
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f'Humidity(%) vs. Latitude\nTime Stamp: {ts}')
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
### Note for ylim - I added the ylim because sometimes a city would pull back a humidity percentage that was greater than
### 100% and it would distort the visualization...
plt.ylim(0,110)
plt.savefig('img/WeatherPy_Humidity.vs.Lat.png')
plt.show()

# %%
############## Cloudiness vs Latitude #######################
y = Complete_WeatherDF.Cloudiness
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f'Cloudiness(%) vs. Latitude\nTime Stamp: {ts}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.savefig('img/WeatherPy_Cloudiness.vs.Lat.png')
plt.show()

# %%
############## WindSpeed vs Latitude #######################
y = Complete_WeatherDF['Wind Speed']
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f'Wind Speed (mph) vs. Latitude\nTime Stamp: {ts}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.savefig('img/WeatherPy_WindSpeed.vs.Lat.png')
plt.show()
