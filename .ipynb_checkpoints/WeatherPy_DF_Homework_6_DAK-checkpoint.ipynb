# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

#Importing this to automate the visualizations time created
from datetime import datetime

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
citylats = []
citylngs = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        citylats.append(lat_lng[0])
        citylngs.append(lat_lng[1])

        # Print the city count to confirm sufficient count
print(f"There are {len(cities)} cities saved")
print(f"There are {len(citylats)} lats saved")
# Out:
# There are 592 cities saved
# There are 592 lats saved

# %%
#################### Creating DataFrame #####################
# Creating empty colummns that will be populated when requesting data via API

temp_dict ={
    "City" : cities,
    "Lat" : citylats,
    "Lng" : citylngs,
    "Temp":"",
    "Humidity":"",
    "Cloudiness":"",
    "Wind Speed":"",
    "City ID":""}

tempDict = pd.DataFrame(temp_dict)
tempDict.head()
# Out:
#              City        Lat         Lng Temp Humidity Cloudiness Wind Speed  \
# 0        oussouye  10.251306  -19.348760
# 1         mataura -26.772421 -142.924229
# 2  severo-kurilsk  43.287429  157.709902
# 3           vaini -85.209221 -175.577465
# 4          torbay  46.572570  -46.587581
#
#   City ID
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Perform API Calls

# %%
#################### OpenWeatherMap API Key #####################
# 
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key + "&q="

#Creating a timestamp so we know exactly when the request was made to gather the weather data
ts = pd.to_datetime(datetime.now())

#Creating Counters to keep track of cities with temp info and cities without temp info
city_number = 0
noinfo = 0

for index, row in tempDict.iterrows():
    city = row['City']
    
    #API Call
    response = requests.get(url + city).json()
    
    try:
       
        
        tempDict.loc[index, 'Temp'] = response['main']['temp']
        tempDict.loc[index, 'Humidity'] = response['main']['humidity']
        tempDict.loc[index, 'Cloudiness'] = response['clouds']['all']
        tempDict.loc[index, 'Wind Speed'] = response['wind']['speed']
        tempDict.loc[index, 'City ID'] = response['id']
        city_number +=1
        print(f"City Number: {city_number} - City Name: {city}")
    except KeyError:
        
#         print(f"{city} did not have a temp")
        noinfo +=1
        continue

print("---------------------------------")
print(f"There are {city_number} cities that DO have info")
print(f"there are {noinfo} cities that DO NOT have any info")
print("----------------------------------")
# Out:
# City Number: 1 - City Name: oussouye
# City Number: 2 - City Name: mataura
# City Number: 3 - City Name: severo-kurilsk
# City Number: 4 - City Name: vaini
# City Number: 5 - City Name: torbay
# City Number: 6 - City Name: hobart
# City Number: 7 - City Name: kapaa
# City Number: 8 - City Name: centenario do sul
# City Number: 9 - City Name: kristiansund
# City Number: 10 - City Name: yellowknife
# City Number: 11 - City Name: saldanha
# City Number: 12 - City Name: college
# City Number: 13 - City Name: rikitea
# City Number: 14 - City Name: alta floresta
# City Number: 15 - City Name: busselton
# City Number: 16 - City Name: upernavik
# City Number: 17 - City Name: chuy
# City Number: 18 - City Name: valparaiso
# City Number: 19 - City Name: parrita
# City Number: 20 - City Name: thompson
# City Number: 21 - City Name: dikson
# City Number: 22 - City Name: chilliwack
# City Number: 23 - City Name: isangel
# City Number: 24 - City Name: cherskiy
# City Number: 25 - City Name: tateyama
# City Number: 26 - City Name: punta arenas
# City Number: 27 - City Name: portland
# City Number: 28 - City Name: puerto suarez
# City Number: 29 - City Name: cape town
# City Number: 30 - City Name: bloomington
# City Number: 31 - City Name: ust-nera
# City Number: 32 - City Name: hilo
# City Number: 33 - City Name: hofn
# City Number: 34 - City Name: laguna
# City Number: 35 - City Name: deputatskiy
# City Number: 36 - City Name: qaanaaq
# City Number: 37 - City Name: trairi
# City Number: 38 - City Name: vao
# City Number: 39 - City Name: bethel
# City Number: 40 - City Name: ndjole
# City Number: 41 - City Name: nikolskoye
# City Number: 42 - City Name: cockburn town
# City Number: 43 - City Name: atuona
# City Number: 44 - City Name: port lincoln
# City Number: 45 - City Name: albany
# City Number: 46 - City Name: longhua
# City Number: 47 - City Name: iqaluit
# City Number: 48 - City Name: fairbanks
# City Number: 49 - City Name: filingue
# City Number: 50 - City Name: chokurdakh
# City Number: 51 - City Name: tual
# City Number: 52 - City Name: flinders
# City Number: 53 - City Name: vrede
# City Number: 54 - City Name: kodiak
# City Number: 55 - City Name: avarua
# City Number: 56 - City Name: port alfred
# City Number: 57 - City Name: nanortalik
# City Number: 58 - City Name: rio grande
# City Number: 59 - City Name: alofi
# City Number: 60 - City Name: beisfjord
# City Number: 61 - City Name: bluff
# City Number: 62 - City Name: jamestown
# City Number: 63 - City Name: georgetown
# City Number: 64 - City Name: ilo
# City Number: 65 - City Name: qandala
# City Number: 66 - City Name: kahului
# City Number: 67 - City Name: palmerston
# City Number: 68 - City Name: cairns
# City Number: 69 - City Name: fiumicino
# City Number: 70 - City Name: lebu
# City Number: 71 - City Name: norman wells
# City Number: 72 - City Name: longyearbyen
# City Number: 73 - City Name: new norfolk
# City Number: 74 - City Name: saint-paul
# City Number: 75 - City Name: port elizabeth
# City Number: 76 - City Name: ribeira grande
# City Number: 77 - City Name: jutai
# City Number: 78 - City Name: pingliang
# City Number: 79 - City Name: leh
# City Number: 80 - City Name: bundaberg
# City Number: 81 - City Name: benjamin constant
# City Number: 82 - City Name: lagoa
# City Number: 83 - City Name: tabuk
# City Number: 84 - City Name: coquimbo
# City Number: 85 - City Name: castro
# City Number: 86 - City Name: kaitangata
# City Number: 87 - City Name: saint george
# City Number: 88 - City Name: bambous virieux
# City Number: 89 - City Name: bathsheba
# City Number: 90 - City Name: ilulissat
# City Number: 91 - City Name: koster
# City Number: 92 - City Name: hithadhoo
# City Number: 93 - City Name: tiksi
# City Number: 94 - City Name: watertown
# City Number: 95 - City Name: barrow
# City Number: 96 - City Name: ushuaia
# City Number: 97 - City Name: la ronge
# City Number: 98 - City Name: gallup
# City Number: 99 - City Name: pitimbu
# City Number: 100 - City Name: botro
# City Number: 101 - City Name: geelong
# City Number: 102 - City Name: road town
# City Number: 103 - City Name: nesna
# City Number: 104 - City Name: yining
# City Number: 105 - City Name: vardo
# City Number: 106 - City Name: port hedland
# City Number: 107 - City Name: oktyabrskiy
# City Number: 108 - City Name: cabo san lucas
# City Number: 109 - City Name: curuca
# City Number: 110 - City Name: dingle
# City Number: 111 - City Name: peruibe
# City Number: 112 - City Name: tuktoyaktuk
# City Number: 113 - City Name: victor harbor
# City Number: 114 - City Name: sur
# City Number: 115 - City Name: san cristobal
# City Number: 116 - City Name: muros
# City Number: 117 - City Name: bredasdorp
# City Number: 118 - City Name: una
# City Number: 119 - City Name: provideniya
# City Number: 120 - City Name: komsomolskiy
# City Number: 121 - City Name: arona
# City Number: 122 - City Name: conceicao da barra
# City Number: 123 - City Name: banda aceh
# City Number: 124 - City Name: tuy hoa
# City Number: 125 - City Name: fortuna
# City Number: 126 - City Name: clyde river
# City Number: 127 - City Name: praia
# City Number: 128 - City Name: himatangi
# City Number: 129 - City Name: pizarro
# City Number: 130 - City Name: vila velha
# City Number: 131 - City Name: piranshahr
# City Number: 132 - City Name: tasiilaq
# City Number: 133 - City Name: henties bay
# City Number: 134 - City Name: sibolga
# City Number: 135 - City Name: kavieng
# City Number: 136 - City Name: guerrero negro
# City Number: 137 - City Name: warrnambool
# City Number: 138 - City Name: san ramon
# City Number: 139 - City Name: neuquen
# City Number: 140 - City Name: souillac
# City Number: 141 - City Name: marzuq
# City Number: 142 - City Name: narsaq
# City Number: 143 - City Name: vostok
# City Number: 144 - City Name: butaritari
# City Number: 145 - City Name: mutis
# City Number: 146 - City Name: kieta
# City Number: 147 - City Name: ginir
# City Number: 148 - City Name: pevek
# City Number: 149 - City Name: te anau
# City Number: 150 - City Name: lebedyn
# City Number: 151 - City Name: aasiaat
# City Number: 152 - City Name: carnarvon
# City Number: 153 - City Name: caravelas
# City Number: 154 - City Name: sandwick
# City Number: 155 - City Name: alekseyevsk
# City Number: 156 - City Name: pisco
# City Number: 157 - City Name: canmore
# City Number: 158 - City Name: bukama
# City Number: 159 - City Name: mana
# City Number: 160 - City Name: vredendal
# City Number: 161 - City Name: ugoofaaru
# City Number: 162 - City Name: geraldton
# City Number: 163 - City Name: roma
# City Number: 164 - City Name: huarmey
# City Number: 165 - City Name: lithakia
# City Number: 166 - City Name: baruun-urt
# City Number: 167 - City Name: dong xoai
# City Number: 168 - City Name: khani
# City Number: 169 - City Name: aklavik
# City Number: 170 - City Name: tuatapere
# City Number: 171 - City Name: saint anthony
# City Number: 172 - City Name: bernalillo
# City Number: 173 - City Name: amet
# City Number: 174 - City Name: wanning
# City Number: 175 - City Name: raudeberg
# City Number: 176 - City Name: sao joao da barra
# City Number: 177 - City Name: faya
# City Number: 178 - City Name: saskylakh
# City Number: 179 - City Name: bukan
# City Number: 180 - City Name: hermanus
# City Number: 181 - City Name: luanda
# City Number: 182 - City Name: teguldet
# City Number: 183 - City Name: cayenne
# City Number: 184 - City Name: maningrida
# City Number: 185 - City Name: lorengau
# City Number: 186 - City Name: deulgaon raja
# City Number: 187 - City Name: muzambinho
# City Number: 188 - City Name: ancud
# City Number: 189 - City Name: mezen
# City Number: 190 - City Name: east london
# City Number: 191 - City Name: laramie
# City Number: 192 - City Name: fort nelson
# City Number: 193 - City Name: liberty
# City Number: 194 - City Name: khurja
# City Number: 195 - City Name: mizan teferi
# City Number: 196 - City Name: kalabo
# City Number: 197 - City Name: soderhamn
# City Number: 198 - City Name: vanavara
# City Number: 199 - City Name: ponta do sol
# City Number: 200 - City Name: lata
# City Number: 201 - City Name: lavrentiya
# City Number: 202 - City Name: taganak
# City Number: 203 - City Name: saint-philippe
# City Number: 204 - City Name: airai
# City Number: 205 - City Name: port hardy
# City Number: 206 - City Name: chicama
# City Number: 207 - City Name: aksha
# City Number: 208 - City Name: novopavlovka
# City Number: 209 - City Name: kabinda
# City Number: 210 - City Name: buchanan
# City Number: 211 - City Name: gat
# City Number: 212 - City Name: macklin
# City Number: 213 - City Name: luderitz
# City Number: 214 - City Name: casa grande
# City Number: 215 - City Name: wagar
# City Number: 216 - City Name: ferkessedougou
# City Number: 217 - City Name: bonthe
# City Number: 218 - City Name: ajdabiya
# City Number: 219 - City Name: kontagora
# City Number: 220 - City Name: kavaratti
# City Number: 221 - City Name: khatanga
# City Number: 222 - City Name: mar del plata
# City Number: 223 - City Name: beira
# City Number: 224 - City Name: faanui
# City Number: 225 - City Name: zyryanka
# City Number: 226 - City Name: vostochnyy
# City Number: 227 - City Name: christchurch
# City Number: 228 - City Name: lumphat
# City Number: 229 - City Name: rovaniemi
# City Number: 230 - City Name: arraial do cabo
# City Number: 231 - City Name: biak
# City Number: 232 - City Name: mogadishu
# City Number: 233 - City Name: wote
# City Number: 234 - City Name: hennenman
# City Number: 235 - City Name: neosho
# City Number: 236 - City Name: belaya gora
# City Number: 237 - City Name: zhanaozen
# City Number: 238 - City Name: tondano
# City Number: 239 - City Name: saint-joseph
# City Number: 240 - City Name: uddevalla
# City Number: 241 - City Name: cap malheureux
# City Number: 242 - City Name: chapais
# City Number: 243 - City Name: pangnirtung
# City Number: 244 - City Name: royton
# City Number: 245 - City Name: puerto ayora
# City Number: 246 - City Name: corner brook
# City Number: 247 - City Name: salalah
# City Number: 248 - City Name: sechura
# City Number: 249 - City Name: santa maria da boa vista
# City Number: 250 - City Name: myitkyina
# City Number: 251 - City Name: moroni
# City Number: 252 - City Name: sioux lookout
# City Number: 253 - City Name: esperance
# City Number: 254 - City Name: lompoc
# City Number: 255 - City Name: sonoita
# City Number: 256 - City Name: milkovo
# City Number: 257 - City Name: promyshlennovskiy
# City Number: 258 - City Name: samarai
# City Number: 259 - City Name: maiduguri
# City Number: 260 - City Name: nunoa
# City Number: 261 - City Name: san quintin
# City Number: 262 - City Name: rostovka
# City Number: 263 - City Name: itoigawa
# City Number: 264 - City Name: urucara
# City Number: 265 - City Name: victoria
# City Number: 266 - City Name: makakilo city
# City Number: 267 - City Name: gizo
# City Number: 268 - City Name: juneau
# City Number: 269 - City Name: quatre cocos
# City Number: 270 - City Name: warri
# City Number: 271 - City Name: scarborough
# City Number: 272 - City Name: kysyl-syr
# City Number: 273 - City Name: kruisfontein
# City Number: 274 - City Name: pachino
# City Number: 275 - City Name: flin flon
# City Number: 276 - City Name: nemuro
# City Number: 277 - City Name: eyl
# City Number: 278 - City Name: ihiala
# City Number: 279 - City Name: mulege
# City Number: 280 - City Name: avera
# City Number: 281 - City Name: ulaanbaatar
# City Number: 282 - City Name: husavik
# City Number: 283 - City Name: arlit
# City Number: 284 - City Name: skibbereen
# City Number: 285 - City Name: brandon
# City Number: 286 - City Name: klaksvik
# City Number: 287 - City Name: surt
# City Number: 288 - City Name: hambantota
# City Number: 289 - City Name: merauke
# City Number: 290 - City Name: beringovskiy
# City Number: 291 - City Name: kalmunai
# City Number: 292 - City Name: sao filipe
# City Number: 293 - City Name: eureka
# City Number: 294 - City Name: aginskoye
# City Number: 295 - City Name: san patricio
# City Number: 296 - City Name: san blas
# City Number: 297 - City Name: shingu
# City Number: 298 - City Name: alice springs
# City Number: 299 - City Name: peleduy
# City Number: 300 - City Name: santa maria
# City Number: 301 - City Name: rapid valley
# City Number: 302 - City Name: kailua
# City Number: 303 - City Name: bani walid
# City Number: 304 - City Name: ketchikan
# City Number: 305 - City Name: jos
# City Number: 306 - City Name: bhadasar
# City Number: 307 - City Name: ayagoz
# City Number: 308 - City Name: lysva
# City Number: 309 - City Name: paamiut
# City Number: 310 - City Name: parkes
# City Number: 311 - City Name: taltal
# City Number: 312 - City Name: amahai
# City Number: 313 - City Name: jumla
# City Number: 314 - City Name: bejar
# City Number: 315 - City Name: vila franca do campo
# City Number: 316 - City Name: luang prabang
# City Number: 317 - City Name: olinda
# City Number: 318 - City Name: bandarbeyla
# City Number: 319 - City Name: katangli
# City Number: 320 - City Name: bogorodskoye
# City Number: 321 - City Name: kempsey
# City Number: 322 - City Name: berlevag
# City Number: 323 - City Name: waipawa
# City Number: 324 - City Name: nouadhibou
# City Number: 325 - City Name: vieux-habitants
# City Number: 326 - City Name: jaffna
# City Number: 327 - City Name: ewa beach
# City Number: 328 - City Name: bellingham
# City Number: 329 - City Name: hvide sande
# City Number: 330 - City Name: mahanoro
# City Number: 331 - City Name: dalvik
# City Number: 332 - City Name: ballina
# City Number: 333 - City Name: zeya
# City Number: 334 - City Name: talnakh
# City Number: 335 - City Name: grindavik
# City Number: 336 - City Name: tiarei
# City Number: 337 - City Name: juybar
# City Number: 338 - City Name: rock sound
# City Number: 339 - City Name: novaya ladoga
# City Number: 340 - City Name: jalu
# City Number: 341 - City Name: genhe
# City Number: 342 - City Name: outlook
# City Number: 343 - City Name: axim
# City Number: 344 - City Name: diplo
# City Number: 345 - City Name: cidreira
# City Number: 346 - City Name: lokomotivnyy
# City Number: 347 - City Name: tivaouane
# City Number: 348 - City Name: adeje
# City Number: 349 - City Name: batemans bay
# City Number: 350 - City Name: los llanos de aridane
# City Number: 351 - City Name: pestravka
# City Number: 352 - City Name: karratha
# City Number: 353 - City Name: evensk
# City Number: 354 - City Name: salisbury
# City Number: 355 - City Name: plaster rock
# City Number: 356 - City Name: bereda
# City Number: 357 - City Name: mahebourg
# City Number: 358 - City Name: hovd
# City Number: 359 - City Name: cedar city
# City Number: 360 - City Name: santona
# City Number: 361 - City Name: at-bashi
# City Number: 362 - City Name: tilichiki
# City Number: 363 - City Name: hasaki
# City Number: 364 - City Name: ilhabela
# City Number: 365 - City Name: yar-sale
# City Number: 366 - City Name: asosa
# City Number: 367 - City Name: san juan bautista
# City Number: 368 - City Name: skjervoy
# City Number: 369 - City Name: lakes entrance
# City Number: 370 - City Name: waddan
# City Number: 371 - City Name: beyneu
# City Number: 372 - City Name: cabangahan
# City Number: 373 - City Name: primorsk
# City Number: 374 - City Name: barra do garcas
# City Number: 375 - City Name: bucak
# City Number: 376 - City Name: monte patria
# City Number: 377 - City Name: san ramon de la nueva oran
# City Number: 378 - City Name: vila
# City Number: 379 - City Name: carmen
# City Number: 380 - City Name: cheyenne
# City Number: 381 - City Name: samarkand
# City Number: 382 - City Name: nioro
# City Number: 383 - City Name: brae
# City Number: 384 - City Name: lashio
# City Number: 385 - City Name: kochki
# City Number: 386 - City Name: charters towers
# City Number: 387 - City Name: pailon
# City Number: 388 - City Name: ngunguru
# City Number: 389 - City Name: sal rei
# City Number: 390 - City Name: yuzhnyy
# City Number: 391 - City Name: oriximina
# City Number: 392 - City Name: nichinan
# City Number: 393 - City Name: cururupu
# City Number: 394 - City Name: bridgetown
# City Number: 395 - City Name: hereford
# City Number: 396 - City Name: marsh harbour
# City Number: 397 - City Name: cartagena
# City Number: 398 - City Name: gondanglegi
# City Number: 399 - City Name: russell
# City Number: 400 - City Name: tazovskiy
# City Number: 401 - City Name: namibe
# City Number: 402 - City Name: ormara
# City Number: 403 - City Name: rockport
# City Number: 404 - City Name: camacha
# City Number: 405 - City Name: adrar
# City Number: 406 - City Name: borba
# City Number: 407 - City Name: shimoda
# City Number: 408 - City Name: athens
# City Number: 409 - City Name: calvinia
# City Number: 410 - City Name: sri aman
# City Number: 411 - City Name: maceio
# City Number: 412 - City Name: porto novo
# City Number: 413 - City Name: nova odesa
# City Number: 414 - City Name: porto walter
# City Number: 415 - City Name: ensley
# City Number: 416 - City Name: walvis bay
# City Number: 417 - City Name: sitka
# City Number: 418 - City Name: toronto
# City Number: 419 - City Name: aqtobe
# City Number: 420 - City Name: baykit
# City Number: 421 - City Name: mocuba
# City Number: 422 - City Name: havelock
# City Number: 423 - City Name: weinan
# City Number: 424 - City Name: mega
# City Number: 425 - City Name: aswan
# City Number: 426 - City Name: mount isa
# City Number: 427 - City Name: mount gambier
# City Number: 428 - City Name: ust-barguzin
# City Number: 429 - City Name: slave lake
# City Number: 430 - City Name: wana
# City Number: 431 - City Name: zhigansk
# City Number: 432 - City Name: cheney
# City Number: 433 - City Name: les trois-ilets
# City Number: 434 - City Name: terrace bay
# City Number: 435 - City Name: harper
# City Number: 436 - City Name: idenao
# City Number: 437 - City Name: anadyr
# City Number: 438 - City Name: chibombo
# City Number: 439 - City Name: haljala
# City Number: 440 - City Name: santa rosa
# City Number: 441 - City Name: pedernales
# City Number: 442 - City Name: dustlik
# City Number: 443 - City Name: preobrazheniye
# City Number: 444 - City Name: general roca
# City Number: 445 - City Name: nelson bay
# City Number: 446 - City Name: lokosovo
# City Number: 447 - City Name: zabaykalsk
# City Number: 448 - City Name: santiago
# City Number: 449 - City Name: angoche
# City Number: 450 - City Name: tselinnoye
# City Number: 451 - City Name: lodja
# City Number: 452 - City Name: alyangula
# City Number: 453 - City Name: grays
# City Number: 454 - City Name: angra dos reis
# City Number: 455 - City Name: marawi
# City Number: 456 - City Name: matay
# City Number: 457 - City Name: conde

# %%
################## Summary of Data and how many cities were removed becuase they didn't have any data #################

# Replace empty strings in the Temp column with NaN
tempDict['Temp'].replace('',np.nan, inplace=True)

# Create new DF with only cities that have temperature data
Complete_WeatherDF = tempDict.dropna(subset=['Temp'])

print(f"The original tempDict Data Frame's shape is: {tempDict.shape}")
print(f"The new DataFrame including only valid cities with temperatures shape is: {Complete_WeatherDF.shape}")
print(f"There were {noinfo} cities in the original tempDict Data Frame that did not have any info.")
Complete_WeatherDF.head()
# Out:
# The original tempDict Data Frame's shape is: (589, 8)
# The new DataFrame including only valid cities with temperatures shape is: (534, 8)
# There were 55 cities in the original tempDict Data Frame that did not have any info.
#          City        Lat         Lng   Temp Humidity Cloudiness Wind Speed  \
# 0  codrington  25.262264  -50.158917  48.00       91          0        2.3
# 1  chokurdakh  77.229931  145.721097  35.58       98         92      15.73
# 2      avarua -56.888146 -165.551409  71.60       94         90       1.12
# 3      atuona  -8.492057 -117.424175  79.14      100          0      13.82
# 4   busselton -64.447843   96.273852  52.59      100          0      20.87
#
#    City ID
# 0  2160063
# 1  2126123
# 2  4035715
# 3  4020109
# 4  2075265

# %%
############### Saving Data Frame to CSV File #########################
Complete_WeatherDF.to_csv('Complete_WeatherDF.csv')
tempDict.to_csv('tempDict_DF.csv')

# %%
############## Temperature vs Latitude #######################
y = Complete_WeatherDF.Temp
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f"Temperature(F) vs. Latitude\nTime Stamp: {ts}")
plt.xlabel('Latitude')
plt.ylabel('Temperature(F)')
plt.savefig('WeatherPy_Temp.vs.Lat.png')
plt.show()

# %%
############## Humidity vs Latitude #######################
y = Complete_WeatherDF.Humidity
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f'Humidity(%) vs. Latitude\nTime Stamp: {ts}')
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.ylim(0,110)
plt.savefig('WeatherPy_Humidity.vs.Lat.png')
plt.show()

# %%
############## Cloudiness vs Latitude #######################
y = Complete_WeatherDF.Cloudiness
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f'Cloudiness(%) vs. Latitude\nTime Stamp: {ts}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.savefig('WeatherPy_Cloudiness.vs.Lat.png')
plt.show()

# %%
############## WindSpeed vs Latitude #######################
y = Complete_WeatherDF['Wind Speed']
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f'Wind Speed (mph) vs. Latitude\nTime Stamp: {ts}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.savefig('WeatherPy_WindSpeed.vs.Lat.png')
plt.show()
